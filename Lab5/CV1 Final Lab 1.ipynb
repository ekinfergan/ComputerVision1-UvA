# %% [markdown]
# <center><img src="https://miro.medium.com/v2/resize:fit:1250/format:webp/1*QgI1t-7yJApi4vQigFgsLQ.jpeg" width=30% ></center>
#
# # <center> Lab Project Part 1: Image Classification using Bag-of-Words </center>
# <center> Computer Vision 1, University of Amsterdam </center>
# <center> Due 23:59, October 21, 2023 (Amsterdam time) </center>
#
# ***
#
# <center>
# <b>TA's: Qi Bi, Avik Pal, Nimi Barazani</b>
#
# Student1 ID: 15216608\
# Student1 Name: Despoina Touska
#
# Student2 ID: 12652954 \
# Student2 Name: Ekin Fergan
#
# Student3 ID: 14804557\
# Student3 Name: Gregory Hok Tjoan Go
#
# Student4 ID: 15194817\
# Student4 Name: Jesse Wiers
# </center>

# %% [markdown]
# # **Instructions**
#
# 1. For both parts of the final project, students are expected to prepare a report. The report should include answers to all questions, written details on implementation approaches, the analysis of the results for different settings and visualizations to illustrate experiments with and performance of your implementation. Grading will primarily be based on the report (i.e. it should be self-contained as much as possible). If the report contains any faulty results or ambiguities, the TA's can take a look at your code to find out what happened.
#
# 2. Do not just provide numbers without explanation, remember to follow the general guidelines and discuss different settings to show you understand the material and the processes at work.
#
# 3. For qualitative evaluation, you are expected to visualize the top-5 and the bottom-5 ranked test images (based on the classifier confidence for the target class) per setup. That means you are supposed to provide a figure for each experimental setup, as discussed in Section 2.6.
#
# **Hint:** Having visual elements such as charts, graphs and plots are always useful for everyone. Keep this in mind while writing your reports.

# %% [markdown]
# # **General Guidelines**
# 1. Aim:
#     - Able to understand the basic Image Recognition/Classification pipeline using a traditional Bag of Words method.
#     - Able to use to python packages for image classification: *matplotlib, cv2, sklearn etc.*
#
# 2. Prerequisite:
#     - Familiarity with Python and relevant packages.
#     - Know the basics of feature descriptors (SIFT, HoG) and machine learning tools (K-means, SVM and etc.).
#
# 3. Guidelines:
#     Students should work on the assignments in their assignment group for **two** weeks.
#
#     Any questions regarding the assignment content can be discussed on Piazza.
#
#     Your source code and report must be handed in together in a zip file (**ID1_ID2_ID3_part1.zip**) before the deadline. Make sure your report follows these guidelines:
#     - *The maximum number of pages for this part is 10 (single-column, including tables and figures). Please express your thoughts concisely.*
#     - *Follow the given instructions and answer all given questions. Briefly describe what you implemented.*
#     - *Show you understand the algorithms and implementations: explain why certain settings produce certain results. When constructing graphs, tables and other figures, make your figures as informative as possible (choose relevant sample sizes, axes, etc.), to illustrate your arguments*
#     - *Tables and figures must be accompanied by a brief description. Do not forget to add a number, a title, and if applicable name and unit of variables in a table, name and unit of axes and legends in a figure.*
#
# 4. The report should be handed in in **PDF-format**. Your code should be handed in in **.ipynb format**. This does not mean you have to make your project in a notebook, it just means it **should be submitted as a notebook**. Be sure to test whether all your functionality works as expected when ran in a notebook. If you use a Conda environment, be sure to include it in your submission.
#
# 5. **Late submissions** are not allowed. Assignments that are submitted after the strict deadline will not be graded. In case of submission conflicts, TAs' system clock is taken as reference. We strongly recommend submitting well in advance, to avoid last minute system failure issues.
# 6. **Plagiarism note**:
# Keep in mind that plagiarism (submitted materials which are not your work) is a serious crime and any misconduct shall be punished with the university regulations.
# This includes the use of ChatGPT and other generative AI tools.
#
# <!-- ### PyTorch versions
# we assume that you are using latest PyTorch version(>=1.4)
#
# ### PyTorch Tutorial & Docs
# This tutorial aims to make you familiar with the programming environment that will be used throughout the course. If you have experience with PyTorch or other frameworks (TensorFlow, MXNet *etc.*), you can skip the tutorial exercises; otherwise, we suggest that you complete them all, as they are helpful for getting hands-on experience.
#
# **Anaconda Environment** We recommend installing \textit{anaconda} for configuring \textit{python} package dependencies, whereas it's also fine to use other environment managers as you like. The installation of anaconda can be found in [anaconda link](https://docs.anaconda.com/anaconda/install/).
#
# **Installation** The installation of PyTorch is available at [install link](https://pytorch.org/get-started/locally/) depending on your device and system.
#
# **Getting start** The 60-minute blitz can be found at [blitz](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html), and and examples are at [examples](https://pytorch.org/tutorials/beginner/pytorch_with_examples.html)
#
# **Documents** There might be potential unknown functions or classes, you shall look through the official documents website ([Docs](https://pytorch.org/docs/stable/index.html)) and figure them out by yourself. (***Think***:} What's the difference between *torch.nn.Conv2d* and *torch.nn.functional.conv2d*?)
# You can learn pytorch from the [tutorial link](https://pytorch.org/tutorials/). The Docs information can be searched at [Docs](https://pytorch.org/docs/stable/index.html). In this assignments, we wish you to form the basic capability of using one of the well-known   -->

# %% [markdown]
# # **1. Introduction**
#
# The goal of the assignment is to implement a system for image classification. In other words, this system should tell if there is an object of given class in an image. You will perform 5-class ({1: *airplanes*, 2: *birds*, 3: *ships*, 4: *horses*, 5: *automobiles*}) image classification based on a bag-of-words approach ([reference](http://www.robots.ox.ac.uk/~az/icvss08_az_bow.pdf)) using SIFT features. [CIFAR10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html) will be used for the task. For each class, the test sub-directories contain 1000 images, and the training sub-directories contain 5000 images. Images are represented as (RGB) 32x32 pixels.
#
# Download the [dataset](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz). The archive contains the files *data_batch_1*, *data_batch_2*, ..., *data_batch_5*, as well as *test_batch*. Download the dataset and make yourself familiar with it by figuring out which images and labels you need for the aforementioned 5 classes.
#
# **Note:** You may also opt to work with a subset of the training images if you choose, as long as this subset includes at least 500 images from each of the 5 classes. This option is to allow for a more manageable workload, especially if computational resources are limited. If applicable, consider the effects of using this smaller set of images on the quality of your implementation.
#
# **Hint:**
# In a real scenario, the public data you use often deviates from your task. You need to figure it out and re-arrange the labels as required using the *lab1_utils.py* file (provided in the zip) as a reference. You may (or may not) choose to use the following code to load the dataset:

# %%
from lab1_utils import CIFAR10
trainset = CIFAR10("./data", train=True, N=1000)
testset = CIFAR10("./data", train=False)

training_data = trainset.data
training_label = trainset.targets
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## **1.1 Training Phase**
#
# Training must be conducted over the training set.
# Later on the training set will be divided into two subsets, one for building the visual vocabulary, and the other for training the classifier.
# Keep in mind that using more samples in training will likely result in better performance. However, if your computational resources are limited and/or your system is slow, it's OK to use less training data to save time.
#
# **Hint:** To debug your code, you can use a small amount of input images/descriptors. Once you are sure everything works properly, you can run your code for the experiment using all the data points.
#
# **Hint:** You are not allowed to use the test images for training purpose.

# %% [markdown]
# ## **1.2 Testing Phase**
#
# You have to test your system using the specified subset of test images. All 1000 test images (per class) should be used at once for testing to observe the full performance. Again, exclude them from training for fair comparison.

# %% [markdown]
# # **2. Bag-of-Words based Image Classification**
#
# Bag-of-Words based Image Classification system contains the following steps:
# 1. Feature extraction and description
# 2. Building a visual vocabulary (use the first subset from the training set)
# 3. Quantify features using visual dictionary (encoding)
# 4. Representing images by frequencies of visual words
# 5. Train the classifier (use the second subset from the training set)
#
# We will consider each step in detail.

# %% [markdown]
# ## **2.1 Feature Extraction and Description**
#
# SIFT descriptors can be extracted from keypoints. You can use SIFT related functions in *OpenCV* for feature extraction.

# %% [markdown]
# ####  **` Q2.1: Extract SIFT descriptors from training datasets based on keypoints. Show two images from each of the five classes (draw the circles with the size of keypoints). (10-pts).`**
#
# **Hint:**
# Check out the Docs of SIFT and related functions for further information in the following [link1](https://docs.opencv.org/master/da/df5/tutorial_py_sift_intro.html) and [link2](https://docs.opencv.org/master/d7/d60/classcv_1_1SIFT.html).

# %%
#####################################################

import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog

# For replicability
np.random.seed(0)

# Sort data using index
idx_list       = np.argsort(training_label)
training_data  = training_data[idx_list]
training_label = training_label[idx_list]

class_names    = ["Plane", "Bird", "Ship", "Horse", "Automobile"]
num_classes    = 5

# Feature Extraction Function
def feature_extractor(training_data, feature='sift', visualize=False): # Alternative feature = hog

    # SIFT
    if (feature == 'sift'):

        # Creating the SIFT/HOG Object
        sift = cv2.xfeatures2d.SIFT_create()
        keypoints   = []
        descriptors = []
        for img in training_data:

            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Grayscaling to reduce complexity
            kp, desc = sift.detectAndCompute(img_gray, None)
            # Ensure that there are descriptors for all images
            if desc is None:

                desc = np.zeros((1, sift.descriptorSize()), np.float32) 
            
            keypoints.append(kp)
            descriptors.append(desc)

        if (visualize == True):
        
            return keypoints, descriptors
    
        else:
        
            return descriptors

    # HOG (for later parts)
    elif (feature == 'hog'):

        features    = []
        images      = []
        for img in training_data:

            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Grayscaling to reduce complexity

            if (visualize == True):
                
                ft, img  = hog(img_gray, pixels_per_cell=(4, 4), visualize=visualize, transform_sqrt=True) # To make 8 cells
                dim_size = int(np.sqrt(ft.shape[0]))
                ft       = ft.reshape((dim_size, dim_size))
                images.append(img)

            else:
                
                ft       = hog(img_gray, pixels_per_cell=(4, 4), transform_sqrt=True) # To make 8 cells
                dim_size = int(np.sqrt(ft.shape[0]))
                ft       = ft.reshape((dim_size, dim_size))

            features.append(ft)

        if (visualize == True):

            return features, images
        
        else:
            
            return features

# Plotting Function (only for SIFT)
def plotter(training_data, training_label, keypoints, class_names, samples=2, figsize=(10, 6)):

    labels  = np.unique(training_label)
    fig, ax = plt.subplots(samples, len(labels), figsize = figsize)
    names   = class_names
    for label in labels:

        ax[0, label].set_title(names[label]) # For the Title
        idx = [label * 1000, label * 1000 + 1] # Because of sorting: Every 1000 images the class changes
        for row, id in enumerate(idx):

            image      = training_data[id]
            image_plot = cv2.drawKeypoints(image, keypoints[id], 0, (255, 0, 0), 
                                           flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
            ax[row, label].imshow(image_plot)
            ax[row, label].axis('off')

    fig.suptitle(f"Keypoints of Sample Training Images", fontsize=14, weight='bold')
    plt.tight_layout()
    plt.show()

######################################################

# %%
######################################################

# Execution
keypoints, descriptors = feature_extractor(training_data, visualize=True)
plotter(training_data, training_label, keypoints, class_names)

######################################################

# %% [markdown]
# ## **2.2 Building Visual Vocabulary**
#
# Here, we will obtain visual words by clustering feature descriptors, so each cluster center is a visual word. Take a subset of all training images (this subset should contain images from ALL categories), extract SIFT descriptors from all of these images, and run k-means clustering (you can use your favourite k-means implementation) on these SIFT descriptors to build your visual vocabulary. Then, take the rest of the training images to calculate a visual dictionary.
#
# You can also use less images, say 100 from each class (exclusive from the previous subset) if your computational resources are limited (remember to analyze the effects). Pre-defined cluster numbers will be the size of your vocabulary. In this question, set its size to 1000.

# %% [markdown]
# ####  **` Q2.2: Building Visual Vocabulary. (10-pts)`**
# Create a visual vocabulary by using K-means clustering. Remember to display the results when the vocabulary subset is 30\%, 40\% and 50\% amount of the training images. The vocabulary size is fixed 1000 in this question.
#
# **Hint 1:** Remember first to debug all the code with a small amount of input images and only when you are sure that code functions correctly run it for training over the larger dataset.
#
# **Hint 2:** You can achieve K-means clustering using either *sklearn* package or *scipy* package.
#
# **Hint 3:** Results of K-means clustering could be shown using a scatter plot. In this case, the high-dimensional SIFT descriptors need to be brought down to a lower (2D) dimension  (*PCA* from *sklearn.decomposition* is one method to do this). For easy visualization, plotting up to 10 clusters would suffice. Check out an example implementation [here](https://www.askpython.com/python/examples/plot-k-means-clusters-python). Note that you are free to follow this approach, or you can show the K-means results in any other appropriate method that drives home your point.

# %%
######################

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

vocabulary_size = 1000

# Function for sampling smaller part of Dataset (with balanced classes)
def data_sampler(descriptors, threshold, training_label):

    sample_desc = []
    for label in np.unique(training_label):

        idx_start = label * 1000
        idx_end   = idx_start + int(threshold * 1000)

        sample_desc.extend(descriptors[idx_start:idx_end])

    return sample_desc

# Combining the Descriptors
def desc_merger(descriptors, threshold, training_label):

    dataset = []
    samples = data_sampler(descriptors, threshold, training_label)
        
    for sample in samples:

        if sample is not None: # Avoiding NoneTypes

            dataset.extend(sample)

    dataset = np.stack(dataset)

    return dataset

# K-Means Execution
def vocab_maker(descriptors, vocabulary_size):
    # For replicability
    np.random.seed(0)
    #print("Shape:", descriptors.shape)
    kmeans = KMeans(n_clusters = vocabulary_size, n_init=8)
    kmeans.fit(descriptors)

    return kmeans

# For Plotting
def vocab_visualizer(descriptors, kmeans, n_to_plot=10, figsize=(10, 6), percentage=10):
    
    # Transforming to 2D space
    pca = PCA(2, svd_solver='full')
    pca.fit(descriptors)
    centroids   = kmeans.cluster_centers_
    centers_2d  = pca.transform(centroids)
    desc_2d     = pca.transform(descriptors)

    # Getting the Data for Each of the Clusters
    predictions = kmeans.predict(descriptors)

    plt.figure(figsize=figsize)
    plt.title(f'Visualization of {n_to_plot} Cluster Centers in 2D Space using {percentage}% Data Subset', weight='bold')
    
    plt.rcParams['axes.axisbelow'] = True # Moving Grid Back
    plt.grid(True, alpha=0.9)

    # Plotting the 2D Data
    for idx in range(n_to_plot):
        
        idx_plot    = np.stack(np.where(predictions == idx))[0]
        data        = desc_2d[idx_plot]
        plt.scatter(data[:, 0], data[:, 1], s=80, alpha=0.7)

    # Plotting the 2D Centroids
    plt.scatter(centers_2d[:n_to_plot, 0], centers_2d[:n_to_plot, 1], s=80, marker= 'x', color='k', label='Cluster Centers')

    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.legend()
    plt.show()

######################

# %%
######################

# Data Loading for Vocabulary Visualization
dataset_30 = desc_merger(descriptors, 0.3, training_label)
vocab_30   = vocab_maker(dataset_30, vocabulary_size)

dataset_40 = desc_merger(descriptors, 0.4, training_label)
vocab_40   = vocab_maker(dataset_40, vocabulary_size)

dataset_50 = desc_merger(descriptors, 0.5, training_label)
vocab_50   = vocab_maker(dataset_50, vocabulary_size)

######################

# %%
######################

# Visualization
vocab_visualizer(dataset_30, vocab_30, percentage=30)
vocab_visualizer(dataset_40, vocab_40, percentage=40)
vocab_visualizer(dataset_50, vocab_50, percentage=50)

######################

# %% [markdown]
# ## **2.3 Encoding Features Using Visual Vocabulary**
#
# Once we have a visual vocabulary, we can represent each image as a collection of visual words. For this purpose, we need to extract feature descriptors (with SIFT) and then assign each descriptor to the closest visual word from the vocabulary.

# %%
######################

def encode_features(all_images_descriptors, kmeans):

    encoded_features = []
    for image_descs in all_images_descriptors:

        if image_descs is not None:

            # Predict cluster centers (wrrds) per descriptor
            closest_words = kmeans.predict(image_descs)
            encoded_features.append(closest_words)
            
        else:

            # Images without descriptors
            encoded_features.append(None)

    return encoded_features

######################

# %%
######################

encoded_features = encode_features(descriptors, vocab_50) # Done here using 50% subset
# Print length of encoded features for each image (0 for no descriptors)
#print([len(feature) if feature is not None else 0 for feature in encoded_features])

######################

# %% [markdown]
# ## **2.4 Representing images by frequencies of visual words**
#
# The next step is the quantization. The idea is to represent each image by a histogram of its visual words. Check out matplotlib's [hist()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html) function. Since different images can have different numbers of features, histograms should be normalized.

# %% [markdown]
# ####  **` Q2.4: Representing images by frequencies of visual words. (5-pts)`**
#
# Pick a subset ratio from the above settings (30%, 40% and 50%). For each class, calculate the frequency of visual words. Visualize the visual words' frequency by histogram. The X-axis is supposed to be the visual word number (e.g.,from 0 to 1000), and the Y-axis is supposed to be the frequency. Describe the similarities and differences.

# %%
######################

def word_plotter(encoded_features, vocab_size, class_names, subset_ratio, figsize=(10, 6)):
    
    # For replicability
    np.random.seed(0)
    for label, class_name in enumerate(class_names):

        # Per class random sampling
        idx_start = int(label * 1000) 
        idx_end   = int(label + 1) * 1000
        indexes   = np.arange(idx_start, idx_end)

        subset_size        = int(len(indexes) * subset_ratio) # Calculate amount of samples desired based on subset_ratio
        subset_random_idxs = np.random.choice(indexes, subset_size, replace=False)

        word_count = np.zeros(vocab_size)
        for i in subset_random_idxs:

            image_features = encoded_features[i]
            # If the i-th image belongs to the current class and has some features, count the words
            if (training_label[i] == label) and (image_features is not None):

                for word in image_features:
                    
                    word_count[word] += 1

        # Normalize to max count
        word_count = word_count / np.max(word_count)
        
        # plotting
        plt.figure(figsize=figsize)
        plt.bar(range(vocab_size), word_count, color='mediumturquoise')
        plt.grid(True)
        plt.title(f"Word Histogram for {class_name} with {int(subset_ratio*100)}% Data", weight='bold')
        plt.xlabel("Visual Words")
        plt.ylabel("Normalized Frequency")
        plt.show()

######################

# %%
######################

# Testing with a subset of 50% of the data
subset_ratio = 0.5
word_plotter(encoded_features, vocabulary_size, class_names, subset_ratio, figsize=(10, 5))

######################

# %% [markdown]
# ## **2.5 Classification**
#
# We will train a classifier per each object class. Now, we take the Support Vector Machine (SVM) as an example. As a result, we will have 5 *binary* classifiers.
#
# Take images from the training set of the related class (should be the ones which you did not use for dictionary calculation). Represent them with histograms of visual words as discussed in the previous section. Use at least 50 training images per class or more, but remember to debug your code first! If you use the default setting, you should have 50 histograms of size 1000. These will be your positive examples.
#
# Then, you will obtain histograms of visual words for images from other classes, again about 50 images per class, as negative examples. Therefore, you will have 200 negative examples.
#
# Now, you are ready to train a classifier. You should repeat it for each class. To classify a new image, you should calculate its visual words histogram as described in Section 2.4 and use the trained SVM classifier to assign it to the most probable object class. (Note that for proper SVM scores you need to use cross-validation to get a proper estimate of the SVM parameters. In this assignment, you do not have to experiment with this cross-validation step).

# %% [markdown]
# ####  **` Q2.5: Classification (5-pts)`**
#
# Utilize SVM and finish classification training.
#
# **Hint:**
# You can use *scikit-learn* software to conduct SVM classification. The relevant documents can be found at this [link](https://scikit-learn.org/stable/modules/svm.html).

# %%
################################

from sklearn.svm import SVC

def create_hists(encoded_features, vocab_size):
    # Count the frequency of each word in each image of the (subset) data
    hists = []
    for image_features in encoded_features:

        if image_features is not None:

            image_hist, _ = np.histogram(image_features, bins=np.arange(0, vocab_size))#, density=True)
            hists.append(image_hist)

        else:

            no_features_hist = np.zeros(vocab_size)
            hists.append(no_features_hist)

    return hists


def get_samples(descriptors, training_label, vocab_size, subset_ratio, n_train=400, n_test=100): # 80 - 20 train-test ratio

    labels     = np.unique(training_label)
    data_train = {n: [] for n in labels}
    data_test  = {n: [] for n in labels}
    idx_test   = {n: [] for n in labels} # For error analysis
    for label in labels:
        # Due to how the initial data was sampled, we can sample from intervals: [300 - 1000, 1300 - 2000, etc.]
        # (^Assuming 30% subset was used)
        train_start = int(label * 1000) + int(subset_ratio * 1000)
        idx_test_t  = np.arange(train_start + n_train, train_start + n_train + n_test)
        idx_test[label] = idx_test_t

        # Select a subset of descriptors of the current class
        desc_train  = descriptors[train_start : train_start + n_train]
        desc_test   = descriptors[train_start + n_train : train_start + n_train + n_test]

        # Create histograms of visual words for the subset
        hist_train  = create_hists(desc_train, vocab_size)
        hist_test   = create_hists(desc_test, vocab_size)

        # Append to the dictionary (hists are arranged by class)
        data_train[label].extend(hist_train)
        data_test[label].extend(hist_test)
    

    for label in labels: # Converting to arrays

        data_train[label] = np.array(data_train[label])
        data_test[label]  = np.array(data_test[label])
        idx_test[label]   = np.array(idx_test[label])
    
    return data_train, data_test, idx_test # All are dicts with [0-4] as keys

# SVM
def svm_classifier(data_train, data_test, indexes, target=0, n_train=400, n_test=100, cw="balanced", **svc_params): # Need class weights to incentivize giving positives
    
    svm      = SVC(probability=True, class_weight=cw, **svc_params)
    # Data Preparation
    labels   = data_train.keys()
    X_train  = []
    X_test   = []
    y_train  = []
    y_test   = []
    idx_list = []

    for label in labels:
        
        X_train.extend(data_train[label])
        X_test.extend(data_test[label])
        idx_list.extend(indexes[label])
        y_train += [1] * n_train if (label == target) else [-1] * n_train
        y_test  += [1] * n_test if (label == target) else [-1] * n_test

    # Conversion
    X_train  = np.array(X_train)
    X_test   = np.array(X_test)
    y_train  = np.array(y_train)
    y_test   = np.array(y_test)
    idx_list = np.array(idx_list)

    # print(len(X_train))
    # print(len(y_train))

    svm.fit(X_train, y_train)
    predictions = svm.predict(X_test)
    conf_scores = svm.predict_proba(X_test).T[1] # Doing it like this returns the confidence in positive predictions

    # Sorting based on Confidence 
    sorting     = np.argsort(conf_scores)[::-1]
    predictions = predictions[sorting]
    y_test      = y_test[sorting]
    conf_scores = conf_scores[sorting]
    idx_list    = idx_list[sorting]

    # print(idx_list)
    # print(conf_scores)
    #print(svm.class_weight_)
    #print(svm.predict_proba(X_test).T[1])
    results     = {'pred': predictions, 'true': y_test, 'conf': conf_scores, 'idxs': idx_list}

    return results


################################

# %%
################################

train_50, test_50, indexes_50 = get_samples(encoded_features, training_label, vocabulary_size, 0.5)
results_50            = {}
for label in range(num_classes):

    results_50[label] = svm_classifier(train_50, test_50, indexes_50, target=label)

################################

# %% [markdown]
# ## **2.6 Evaluation**
#
# To evaluate your system, you should take all the test images from all classes and rank them based on each binary classifier. In other words, you should classify each test image with each classifier and then sort them based on the classification score. As a result, you will have five lists of test images. Ideally, you would have images with airplanes on the top of your list which is created based on your airplane classifier, and images with cars on the top of your list which is created based on your car classifier, and so on.
#
# In addition to the qualitative analysis, you should measure the performance of the system quantitatively with the Mean Average Precision (mAP) over all classes. The mAP for a single class c is defined as
# \begin{equation}
# \frac{1}{m_c} \sum_{i=1}^{n} \frac{f_c(x_i)}{i}
# \end{equation}
# where $n$ is the number of images ($n=50\times 5=250$), $m$ is the number of images of class $c$  ($m_c=50$), $x_i$ is the $i^{th}$ image in the ranked list $X = \left \{ x_1, x_2, \dots, x_n  \right \}$, and finally, $f_c$ is a function which returns the number of images of class $c$ in the first $i$ images if $x_i$ is of class $c$, and 0 otherwise. To illustrate, if we want to retrieve $R$ and we get the following sequence: $[R, R, T, R, T, T, R, T]$, then $n = 8$, $m = 4$, and $AP(R, R, T, R, T, T, R) = \frac{1}{4} \left (  \frac{1}{1} + \frac{2}{2} + \frac{0}{3} + \frac{3}{4} + \frac{0}{5} + \frac{0}{6} + \frac{4}{7} + \frac{0}{8} \right )$.

# %% [markdown]
# ####  **` Q2.6: Evaluation and Discussion (30-pts)`**
#
# Show the evaluation results and describe. The report should include the analysis of the results for different settings such as:
# - mAP based on different subset ratios to create the vocabulary list (30%, 40% and 50%) under the fixed vocabulary size 1000.
# - Based on the ratio among the above four settings that lead to the best performance, change the vocabulary sizes to different sizes (500, 1000 and 1500). Report and discuss the mAP.
# - Based on the above experiments, find the best setting. Report the mAP based on SIFT descriptor and HoG descriptor.
# - Visualize the top-5 and the bottom-5 ranked test images (based on the classifier confidence for the target class) under the best setting.
# - The impact of the hyper-parameters of SVM.
#
# **Hint 1:**
# To alleviate the working load, the discussion on the impact of SVM’s hyper-parameter settings only need to based on the optimal settings from the first three questions.
#
# **Hint 2:**
# Be sure to discuss the differences between different settings such as vocabulary sizes in your report.
#
# **Hint 3:**
# You can use *skimage.feature.hog* to extract HoG descriptor. The relevant documents can be found at [link](https://scikit-image.org/docs/dev/api/skimage.feature.html?highlight=hog#skimage.feature.hog).

# %%
################################

# For MAP Calculation
def map_scorer(y_true, y_pred):

    assert (len(y_true) == len(y_pred)), "Length mismatch between targets and predictions"
    # For m
    m = np.sum([y_true == 1])
    sum_f = 0
    for idx in range(1, len(y_true) + 1):

        matches = np.sum([y_pred[:idx] == 1]) if (y_pred[idx-1] == 1) and (y_pred[idx-1] == y_true[idx-1]) else 0
        #print(matches, idx)
        sum_f  += matches / idx

    return sum_f / m

# Plotting Images with Highest/Lowest confidence scores
def conf_plotter(images, indexes, confidences, class_name, mode = 'h', n_plot=5, figsize=(10, 4)): # Sorted indexes and confidences
    # needed here, mode is either h(ighest) or lowest
    rank    = "Highest" if (mode == 'h') else "Lowest"
    fig, ax = plt.subplots(1, n_plot, figsize=figsize)
    fig.suptitle(f"Top {n_plot} {rank} Confidence Scores for the {class_name} Classifier", fontsize=14, weight='bold')
    for n in range(n_plot):

        curr_idx = indexes[-(n+1)] if (mode == 'l') else indexes[n]
        n_idx    = -(n+1) if (mode == 'l') else n
        img_curr = images[curr_idx]
        
        ax[n].set_title(f"Confidence\nScore: {round(confidences[n_idx], 4)}")
        ax[n].imshow(img_curr)
        ax[n].axis('off')

    plt.tight_layout()
    plt.show()

################################

# %%
################################

def pipeline(images, threshold, training_label, class_names, num_classes, vocab_size, ftype='sift', plot='off', **svc_params):
    
    print(f"BAG OF VISUAL WORDS RUN USING {ftype.upper()} FEATURES")
    print("=======================================================\n")

    # Step 1) Feature Extraction
    print("Extracting Features...")
    features = feature_extractor(images, feature=ftype, visualize=False)

    # Step 2) Vocabulary Generation
    print("Generating Vocabulary...")
    train_data = desc_merger(features, threshold, training_label) # Subset selection
    data_vocab = vocab_maker(train_data, vocab_size) # K-NN Generation

    # Step 3) Feature Encoding using Vocabulary
    print("Encoding Features...")
    encoded_features = encode_features(features, data_vocab)

    # Step 4) Testing and Result Generation
    print("Performing Testing...\n")
    data_train, data_test, idx_test = get_samples(encoded_features, training_label, vocab_size, 0.5) # With how the sampling works this ensures the same training/test data
    results = {}
    for label in range(num_classes):

        # Getting Class Name
        class_name     = class_names[label]

        # Classification
        class_results  = svm_classifier(data_train, data_test, idx_test, target=label, **svc_params) # Classification using the points _not_ used for SVM or training
        results[label] = class_results # Saving to result dictionary
        map_score      = map_scorer(class_results['true'], class_results['pred'])

        # (Optional) Step 5) Visualization
        if (plot == 'on'):
            
            indexes     = class_results['idxs']
            confidences = class_results['conf']
            
            conf_plotter(images, indexes, confidences, class_name, mode = 'h', n_plot=num_classes)
            conf_plotter(images, indexes, confidences, class_name, mode = 'l', n_plot=num_classes)
        
        print(f"mAP Score for Class {class_name}: {map_score}")

    print("\nPipeline Done!")
    print("=======================================================\n")

    return results

################################

# %%
################################

# Cell Containing Results for Subset Size Sweeping

final_sub = {}
# 1) Different Subset Sizes
for thresh in [0.3, 0.4, 0.5]:

    print("Generating Results for Subset Size:", thresh)
    final_sub[thresh] = pipeline(images=training_data,
                                 threshold=thresh, 
                                 training_label=training_label, 
                                 class_names=class_names, 
                                 num_classes=num_classes, 
                                 vocab_size=vocabulary_size,
                                 ftype="sift", 
                                 plot='off')

################################
# Out:
# Generating Results for Subset Size: 0.3
# BAG OF VISUAL WORDS RUN USING SIFT FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.41
# mAP Score for Class Bird: 0.32
# mAP Score for Class Ship: 0.38
# mAP Score for Class Horse: 0.33
# mAP Score for Class Automobile: 0.33
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Subset Size: 0.4
# BAG OF VISUAL WORDS RUN USING SIFT FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.39
# mAP Score for Class Bird: 0.35
# mAP Score for Class Ship: 0.38
# mAP Score for Class Horse: 0.3
# mAP Score for Class Automobile: 0.27
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Subset Size: 0.5
# BAG OF VISUAL WORDS RUN USING SIFT FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.52
# mAP Score for Class Bird: 0.3
# mAP Score for Class Ship: 0.38
# mAP Score for Class Horse: 0.35
# mAP Score for Class Automobile: 0.31
#
# Pipeline Done!
# =======================================================

# %%
################################

# Cell Containing Results for Vocab Size Sweeping

final_vocab = {}
# 2) Different Vocabulary Sizes
for vocab_size in [500, 1500]: # We already know the result for 1000 so it is not necessary here

    print("Generating Results for Vocabulary Size:", vocab_size)
    final_vocab[vocab_size] = pipeline(images=training_data,
                                       threshold=0.5,
                                       training_label=training_label, 
                                       class_names=class_names, 
                                       num_classes=num_classes, 
                                       vocab_size=vocab_size,
                                       ftype="sift", 
                                       plot='off')

################################
# Out:
# Generating Results for Vocabulary Size: 500
# BAG OF VISUAL WORDS RUN USING SIFT FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.48
# mAP Score for Class Bird: 0.39
# mAP Score for Class Ship: 0.48
# mAP Score for Class Horse: 0.44
# mAP Score for Class Automobile: 0.42
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Vocabulary Size: 1500
# BAG OF VISUAL WORDS RUN USING SIFT FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...

# %%
################################

# Cell Containing Results for Feature Type Sweeping

final_feat = {}
feature    = 'hog' # Again, already have SIFT result above
# 3) Different Features
print("Generating Results for Feature Type:", feature.upper())
final_feat[feature] = pipeline(images=training_data,
                               threshold=0.5,
                               training_label=training_label, 
                               class_names=class_names, 
                               num_classes=num_classes, 
                               vocab_size=500,
                               ftype=feature, 
                               plot='off')

################################
# Out:
# Generating Results for Feature Type: HOG
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.53
# mAP Score for Class Bird: 0.55
# mAP Score for Class Ship: 0.55
# mAP Score for Class Horse: 0.67
# mAP Score for Class Automobile: 0.63
#
# Pipeline Done!
# =======================================================

# %%
################################

# Cell Containing Visualization of Optimal Results

# 4) Visualization
visual = pipeline(images=training_data,
                  threshold=0.3, # Best thus far (may need to reevaluate) 
                  training_label=training_label, 
                  class_names=class_names, 
                  num_classes=num_classes, 
                  vocab_size=500,
                  ftype='hog', 
                  plot='on')

################################
# Out:
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
# mAP Score for Class Plane: 0.53
# mAP Score for Class Bird: 0.55
# mAP Score for Class Ship: 0.55
# mAP Score for Class Horse: 0.67
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Gregory Go\.github\ComputerVision1-UvA\Lab5\CV1 Final Lab 1.ipynb Cell 36 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> ################################
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=2'>3</a> # Cell Containing Visualization of Optimal Results
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=4'>5</a> # 4) Visualization
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=5'>6</a> visual = pipeline(images=training_data,
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=6'>7</a>                   threshold=0.3, # Best thus far (may need to reevaluate)
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=7'>8</a>                   training_label=training_label,
#       <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=8'>9</a>                   class_names=class_names,
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a>                   num_classes=num_classes,
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=10'>11</a>                   vocab_size=500,
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=11'>12</a>                   ftype='hog',
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=12'>13</a>                   plot='on')
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=14'>15</a> ################################
#
# c:\Users\Gregory Go\.github\ComputerVision1-UvA\Lab5\CV1 Final Lab 1.ipynb Cell 36 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=27'>28</a> class_name     = class_names[label]
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=29'>30</a> # Classification
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=30'>31</a> class_results  = svm_classifier(data_train, data_test, idx_test, target=label, **svc_params) # Classification using the points _not_ used for SVM or training
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=31'>32</a> results[label] = class_results # Saving to result dictionary
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=32'>33</a> map_score      = map_scorer(class_results['true'], class_results['pred'])
#
# c:\Users\Gregory Go\.github\ComputerVision1-UvA\Lab5\CV1 Final Lab 1.ipynb Cell 36 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=81'>82</a> idx_list = np.array(idx_list)
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=83'>84</a> # print(len(X_train))
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=84'>85</a> # print(len(y_train))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=86'>87</a> svm.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=87'>88</a> predictions = svm.predict(X_test)
#      <a href='vscode-notebook-cell:/c%3A/Users/Gregory%20Go/.github/ComputerVision1-UvA/Lab5/CV1%20Final%20Lab%201.ipynb#X50sZmlsZQ%3D%3D?line=88'>89</a> conf_scores = svm.predict_proba(X_test).T[1] # Doing it like this returns the confidence in positive predictions
#
# File c:\Users\Gregory Go\anaconda3\envs\CV1_project\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Gregory Go\anaconda3\envs\CV1_project\lib\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File c:\Users\Gregory Go\anaconda3\envs\CV1_project\lib\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
################################

# Cell Containing Results for Parameter Sweeping

final_sweep = {}
C_vals      = [0.25, 0.5, 1, 1.5, 2]
kernels     = ['linear', 'poly', 'rbf']
# 5) Parameter Sweeping
for C in C_vals:

    for kernel in kernels:

        svc_params = {'C': C, 'kernel': kernel}
        idx_name   = kernel + "_" + str(C)
        print("Generating Results for Parameters:", idx_name)

        final_sweep[idx_name] = pipeline(images=training_data,
                                         threshold=0.3, # Best thus far (may need to reevaluate) 
                                         training_label=training_label, 
                                         class_names=class_names, 
                                         num_classes=num_classes, 
                                         vocab_size=500,
                                         ftype='hog', 
                                         plot='off',
                                         **svc_params)

################################
# Out:
# Generating Results for Parameters: linear_0.25
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.58
# mAP Score for Class Bird: 0.59
# mAP Score for Class Ship: 0.6
# mAP Score for Class Horse: 0.57
# mAP Score for Class Automobile: 0.72
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: poly_0.25
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.14
# mAP Score for Class Bird: 0.33
# mAP Score for Class Ship: 0.18
# mAP Score for Class Horse: 0.75
# mAP Score for Class Automobile: 0.17
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: rbf_0.25
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.72
# mAP Score for Class Bird: 0.75
# mAP Score for Class Ship: 0.64
# mAP Score for Class Horse: 0.81
# mAP Score for Class Automobile: 0.82
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: linear_0.5
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.58
# mAP Score for Class Bird: 0.58
# mAP Score for Class Ship: 0.55
# mAP Score for Class Horse: 0.54
# mAP Score for Class Automobile: 0.68
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: poly_0.5
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.21
# mAP Score for Class Bird: 0.25
# mAP Score for Class Ship: 0.2
# mAP Score for Class Horse: 0.58
# mAP Score for Class Automobile: 0.28
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: rbf_0.5
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.65
# mAP Score for Class Bird: 0.68
# mAP Score for Class Ship: 0.64
# mAP Score for Class Horse: 0.74
# mAP Score for Class Automobile: 0.75
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: linear_1
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.58
# mAP Score for Class Bird: 0.57
# mAP Score for Class Ship: 0.59
# mAP Score for Class Horse: 0.56
# mAP Score for Class Automobile: 0.66
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: poly_1
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.19
# mAP Score for Class Bird: 0.16
# mAP Score for Class Ship: 0.17
# mAP Score for Class Horse: 0.34
# mAP Score for Class Automobile: 0.22
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: rbf_1
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.56
# mAP Score for Class Bird: 0.54
# mAP Score for Class Ship: 0.54
# mAP Score for Class Horse: 0.68
# mAP Score for Class Automobile: 0.69
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: linear_1.5
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.58
# mAP Score for Class Bird: 0.57
# mAP Score for Class Ship: 0.6
# mAP Score for Class Horse: 0.55
# mAP Score for Class Automobile: 0.63
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: poly_1.5
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.18
# mAP Score for Class Bird: 0.12
# mAP Score for Class Ship: 0.15
# mAP Score for Class Horse: 0.32
# mAP Score for Class Automobile: 0.17
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: rbf_1.5
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.46
# mAP Score for Class Bird: 0.48
# mAP Score for Class Ship: 0.39
# mAP Score for Class Horse: 0.56
# mAP Score for Class Automobile: 0.64
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: linear_2
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.55
# mAP Score for Class Bird: 0.53
# mAP Score for Class Ship: 0.57
# mAP Score for Class Horse: 0.53
# mAP Score for Class Automobile: 0.68
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: poly_2
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.17
# mAP Score for Class Bird: 0.12
# mAP Score for Class Ship: 0.15
# mAP Score for Class Horse: 0.31
# mAP Score for Class Automobile: 0.17
#
# Pipeline Done!
# =======================================================
#
# Generating Results for Parameters: rbf_2
# BAG OF VISUAL WORDS RUN USING HOG FEATURES
# =======================================================
#
# Extracting Features...
# Generating Vocabulary...
# Encoding Features...
# Performing Testing...
#
# mAP Score for Class Plane: 0.43
# mAP Score for Class Bird: 0.38
# mAP Score for Class Ship: 0.34
# mAP Score for Class Horse: 0.52
# mAP Score for Class Automobile: 0.61
#
# Pipeline Done!
# =======================================================

# %% [markdown]
#  # Individual Contribution Report *(Mandatory)*
#
# Because we want each student to contribute fairly to the submitted work, we ask you to fill out the textcells below. Write down your contribution to each of the assignment components in percentages. Naturally, percentages for one particular component should add up to 100% (e.g. 30% - 30% - 40%). No further explanation has to be given.

# %% [markdown]
# Name: Despoina Touska
#
# Contribution on research: 25%\
# Contribution on programming: 25%\
# Contribution on writing: 25%

# %% [markdown]
# Name: Ekin Fergan
#
# Contribution on research: 25%\
# Contribution on programming: 25%\
# Contribution on writing: 25%

# %% [markdown]
# Name: Gregory Hok Tjoan Go
#
# Contribution on research: 25%\
# Contribution on programming: 25%\
# Contribution on writing: 25%

# %% [markdown]
# Name: Jesse Wiers
#
# Contribution on research: 25%\
# Contribution on programming: 25%\
# Contribution on writing: 25%

# %% [markdown]
#  # -End of Notebook-
